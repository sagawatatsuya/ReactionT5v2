# %%
# similar=1,3,5; top=1,3,5
top1_similar1 = [14.3, 14.3, 14, 14.7, 14.8]
top1_similar3 = [14.2, 13.6, 13.8, 13.7, 14.7]
top1_similar5 = [14.5, 13.9, 13.9, 14.1, 13.6]
top1_similar0 = [20.8, 30.4, 34.8, 46.1, 54.7]

# plot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, figsize=(8, 5))


ax.plot([10,30,50,100,200], top1_similar0, "s-", label='no similar reaction', color='red', alpha=0.7)
ax.plot([10,30,50,100,200], top1_similar1, "o-", label='top1 similar reaction', color='blue', alpha=0.7)
ax.plot([10,30,50,100,200], top1_similar3, "o--", label='top3 similar reaction', color='green', alpha=0.7)
ax.plot([10,30,50,100,200], top1_similar5, "^:", label='top5 similar reaction', color='orange', alpha=0.7)

plt.ylim(10, 60)
ax.set_xticks([10,30,50,100,200])
ax.set_xticklabels([10,30,50,100,200], fontsize=12)
ax.set_yticks([10,20,30,40,50,60])
ax.set_yticklabels([10,20,30,40,50,60], fontsize=12)
# plt.tight_layout()
ax.legend(loc="best", fontsize=12)
